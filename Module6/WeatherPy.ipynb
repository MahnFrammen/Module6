# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (1.26.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\bigmo\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\bigmo\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\bigmo\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# %pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (1.12.0)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from scipy) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\bigmo\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# %pip install pprintpp
# Out:
# Requirement already satisfied: pprintpp in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (0.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\bigmo\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from requests) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\bigmo\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
pip install TIME-python
# Out:
# Requirement already satisfied: TIME-python in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (0.0.17)
# Requirement already satisfied: dipy in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from TIME-python) (1.8.0)
# Requirement already satisfied: nibabel in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from TIME-python) (5.2.0)
# Requirement already satisfied: numpy in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from TIME-python) (1.26.3)
# Requirement already satisfied: scipy in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from TIME-python) (1.12.0)
# Requirement already satisfied: cython!=0.29.29,>=0.29.24 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from dipy->TIME-python) (3.0.8)
# Requirement already satisfied: h5py>=3.1.0 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from dipy->TIME-python) (3.10.0)
# Requirement already satisfied: packaging>=21 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from dipy->TIME-python) (23.2)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from dipy->TIME-python) (4.66.1)
# Requirement already satisfied: trx-python>=0.2.9 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from dipy->TIME-python) (0.2.9)
# Requirement already satisfied: colorama in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.30.0->dipy->TIME-python) (0.4.6)
# Requirement already satisfied: setuptools-scm in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from trx-python>=0.2.9->dipy->TIME-python) (8.0.4)
# Requirement already satisfied: deepdiff in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from trx-python>=0.2.9->dipy->TIME-python) (6.7.1)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from deepdiff->trx-python>=0.2.9->dipy->TIME-python) (4.1.0)
# Requirement already satisfied: setuptools in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from setuptools-scm->trx-python>=0.2.9->dipy->TIME-python) (69.0.3)
# Requirement already satisfied: typing-extensions in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from setuptools-scm->trx-python>=0.2.9->dipy->TIME-python) (4.9.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\bigmo\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\bigmo\appdata\local\programs\python\python312\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\bigmo\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy #https://github.com/wingchen/citipy

# %%
import requests
from pprint import pprint

weather_api_key = "59497c1ce13b25796ec931a58fd75e19"
city_name = "London"  # Replace with the desired city name

url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q={city_name}"
response = requests.get(url).json()

pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 51.5085, 'lon': -0.1257},
#  'dt': 1707623796,
#  'id': 2643743,
#  'main': {'feels_like': 278.6,
#           'humidity': 93,
#           'pressure': 985,
#           'temp': 280.65,
#           'temp_max': 281.55,
#           'temp_min': 279.57},
#  'name': 'London',
#  'rain': {'1h': 0.17},
#  'sys': {'country': 'GB',
#          'id': 2075535,
#          'sunrise': 1707636197,
#          'sunset': 1707671181,
#          'type': 2},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 90, 'speed': 3.09}}

# %%
# Empty list for holding the latitude and longitude combinations
lat_lons = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lon_range = (-180, 180)

# Create a set of random lat and lon combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lons = np.random.uniform(lon_range[0], lon_range[1], size=1500)
lat_lons = zip(lats, lons)

# Identify nearest city for each lat, lon combination
for lat_lon in lat_lons:
    city = citipy.nearest_city(lat_lon[0], lat_lon[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 567

# %%
cities
# Out:
# ['puerto natales',
#  "kapa'a",
#  'port elizabeth',
#  'east london',
#  'crane',
#  'salaqi',
#  'bilibino',
#  'albany',
#  'vernon',
#  'edinburgh of the seven seas',
#  'wailua homesteads',
#  'kudahuvadhoo',
#  'invercargill',
#  'marat',
#  'papatowai',
#  'hermanus',
#  'ilulissat',
#  'port-aux-francais',
#  'mejit',
#  'el calafate',
#  'coquimbo',
#  'manokwari',
#  'chateaubelair',
#  'ribeira grande',
#  'waitangi',
#  'muynoq',
#  'grytviken',
#  'port mathurin',
#  'nemuro',
#  'ambalangoda',
#  'utrik',
#  'tura',
#  'ushuaia',
#  'taiohae',
#  'arno',
#  'oxford',
#  'urengoy',
#  'tolanaro',
#  'tralee',
#  'petropavlovsk-kamchatsky',
#  'sofiyivka',
#  'albertina',
#  'adamstown',
#  'kingston',
#  'enoch',
#  'cabo san lucas',
#  'villa gesell',
#  'hithadhoo',
#  'stanley',
#  'taulaga',
#  'beloyarskiy',
#  'maine soroa',
#  'vilyuysk',
#  'bargara',
#  'bonny',
#  'lompoc',
#  'baldock',
#  'inhambane',
#  'chonchi',
#  'cill airne',
#  'sisimiut',
#  'punta arenas',
#  'luderitz',
#  'lambton shores',
#  'salalah',
#  'aransas pass',
#  'olonkinbyen',
#  'talnakh',
#  'blackmans bay',
#  'fort bragg',
#  'barreirinhas',
#  'constantia',
#  'kodinsk',
#  'kapuskasing',
#  'revda',
#  'avarua',
#  'puerto san carlos',
#  'vadso',
#  'sinabang',
#  'afaahiti',
#  'dali',
#  'hood river',
#  'isafjordur',
#  'san ignacio de velasco',
#  'yellowknife',
#  'kibre mengist',
#  'bandarbeyla',
#  'tera',
#  'ketchikan',
#  'carnarvon',
#  'dudinka',
#  'luanda',
#  'antonio enes',
#  'sitka',
#  'newman',
#  'nuuk',
#  'salinas',
#  'callao',
#  'tazacorte',
#  'vuktyl',
#  'tiksi',
#  'abbeville',
#  'hihifo',
#  'kralendijk',
#  'maiurno',
#  'qaqortoq',
#  'nagqu',
#  'hawaiian paradise park',
#  'toga village',
#  'ambon',
#  'kismayo',
#  'nha trang',
#  'lebu',
#  'cuero',
#  'egilsstadir',
#  'forster',
#  'itaituba',
#  'sittwe',
#  'keflavik',
#  'vilyuchinsk',
#  'buzuluk',
#  'paita',
#  'puerto baquerizo moreno',
#  'quepos',
#  'altay',
#  'saipan',
#  'dalandzadgad',
#  'nova vicosa',
#  'minas de marcona',
#  'alto parana',
#  'shache',
#  'drobeta-turnu severin',
#  'mersa matruh',
#  'lamu',
#  'west island',
#  'klaksvik',
#  'ust-nera',
#  'tamandare',
#  'tazovsky',
#  'aitape',
#  'puning',
#  'bredasdorp',
#  'iqaluit',
#  'jamestown',
#  'yallahs',
#  'georgetown',
#  'bethel',
#  'wad rawah',
#  'kerikeri',
#  'gadzhiyevo',
#  'rimouski',
#  'ploneour-lanvern',
#  'laojunmiao',
#  'malabar',
#  'whitehorse',
#  'holyhead',
#  'kununurra',
#  'sao felix do xingu',
#  'pisco',
#  'juan griego',
#  'prince rupert',
#  'new norfolk',
#  'camarinas',
#  'nabire',
#  'kodiak',
#  'mahina',
#  'hasaki',
#  'yanam',
#  'santiago de cao',
#  'bubaque',
#  'gisborne',
#  'rongelap',
#  'puerto ayora',
#  'remire-montjoly',
#  'badger',
#  'guarapari',
#  'kristiansund',
#  'margate',
#  'at taj',
#  'kwang binh',
#  'chibougamau',
#  'niafunke',
#  'dubbo',
#  'road town',
#  'kupang',
#  'bouafle',
#  'lagoa',
#  'bontang',
#  'tauranga',
#  'port alfred',
#  'udachny',
#  'margaret river',
#  'queenstown',
#  'hammerfest',
#  'rye',
#  'lerwick',
#  'piti village',
#  'kidal',
#  'kuanda',
#  'mora',
#  'wau',
#  'island harbour',
#  'al kharijah',
#  'north lakhimpur',
#  'holualoa',
#  'brisas de zicatela',
#  'uturoa',
#  'lorengau',
#  'pimentel',
#  'selkirk',
#  'arar',
#  'tofol',
#  'nole',
#  'iskateley',
#  'valparaiso',
#  'usogorsk',
#  'hami',
#  'paka',
#  'aasiaat',
#  'alappuzha',
#  'tefe',
#  'palikir - national government center',
#  'jaru',
#  'pokaran',
#  'longyearbyen',
#  'fale old settlement',
#  'rudnyy',
#  'jayapura',
#  'selfoss',
#  'khoyniki',
#  'guaimaca',
#  'enewetak',
#  'tual',
#  'belyy yar',
#  'atafu village',
#  "ust'-ilimsk",
#  'igarka',
#  'mahibadhoo',
#  'ballina',
#  'tobelo',
#  'klyuchi',
#  'gumdag',
#  'betio village',
#  'kalaleh',
#  "st. john's",
#  'aleksandrov gay',
#  'college',
#  'puerto armuelles',
#  'shingu',
#  'bir el hafey',
#  'ashkasham',
#  'anadyr',
#  'san jose de jachal',
#  'laminusa',
#  'midvagur',
#  'aljezur',
#  'san miguel panixtlahuaca',
#  'victoria falls',
#  'ancenis',
#  'douliu',
#  'gakem',
#  'bonthe',
#  'saint-philippe',
#  'bathsheba',
#  'chisec',
#  'polyarnyy',
#  'benguela',
#  'san patricio',
#  'terbuny',
#  'puerto madryn',
#  'touros',
#  'saint-francois',
#  'gao',
#  'papao',
#  'tandil',
#  'shiqian',
#  'leer',
#  'arraial do cabo',
#  'thompson',
#  'ulaangom',
#  'chicoana',
#  'susuman',
#  'xilin hot',
#  'newnham',
#  'katsuura',
#  'yelizovo',
#  'maputo',
#  'la ronge',
#  'scarborough',
#  'kilindoni',
#  'wadesboro',
#  'port lincoln',
#  'yakakent',
#  'esmeraldas',
#  'cururupu',
#  'ghat',
#  'moldova noua',
#  'manacapuru',
#  'jianguang',
#  'santa rosa del sur',
#  'flying fish cove',
#  'alice springs',
#  'bandar abbas',
#  'saint-pierre',
#  'bardai',
#  'kosh-agach',
#  'brookings',
#  'olyokminsk',
#  'conduaga',
#  'acarau',
#  'tieli',
#  'codrington',
#  'holmsund',
#  'malango',
#  'muroto-misakicho',
#  'turrialba',
#  'lihue',
#  'panaba',
#  'ola',
#  'shimoda',
#  'kone',
#  'mount pearl',
#  'saint john',
#  'tres marias',
#  'winnipeg',
#  'lugovoy',
#  'dabou',
#  'isola di capo rizzuto',
#  'senta',
#  'patong',
#  'kargasok',
#  'richards bay',
#  'muisne',
#  "mil'kovo",
#  'hadibu',
#  'maryville',
#  'bodo',
#  'ulsteinvik',
#  'tutoia',
#  'arawa',
#  "nuku'alofa",
#  'coahuayana de hidalgo',
#  'seguela',
#  'xai-xai',
#  'pandan',
#  'guiuan',
#  'ghormach',
#  'lensk',
#  'guelendeng',
#  'lincheng',
#  'alotau',
#  'anchorage',
#  'truth or consequences',
#  'petra',
#  'santo antonio do ica',
#  'lospalos',
#  "governor's harbour",
#  'armacao de buzios',
#  'akureyri',
#  'kavieng',
#  'howrah',
#  'south grafton',
#  'santa ana',
#  'al jawf',
#  'tynda',
#  'ko pha ngan',
#  'haiku-pauwela',
#  'ca mau',
#  'maisi',
#  'jieshou',
#  'raja',
#  'cargados carajos',
#  'noumea',
#  'vitebsk',
#  'daru',
#  'bikenibeu village',
#  'kirensk',
#  'kalix',
#  'puerto deseado',
#  'paraiso',
#  'ilha de mocambique',
#  'vorgashor',
#  'santo antonio',
#  'plastun',
#  'takestan',
#  'el granada',
#  'fort irwin',
#  'abhar',
#  'namtsy',
#  'strezhevoy',
#  'nakamura',
#  'omdurman',
#  'grand falls-windsor',
#  'guatrache',
#  'korla',
#  'katabu',
#  'turpan',
#  'nova sintra',
#  'hotan',
#  'san antonio de pale',
#  'cidreira',
#  'galveston',
#  'qarshi',
#  "nar'yan-mar",
#  'pangoa',
#  'zaio',
#  'sao joao da barra',
#  'farah',
#  'mutare',
#  'alofi',
#  'sorgun',
#  'puerto colombia',
#  'buckeye',
#  'edd',
#  'karratha',
#  'ciudad del carmen',
#  'mitu',
#  'twin falls',
#  'yuzhno-kurilsk',
#  'happy valley-goose bay',
#  'devinuwara',
#  'novyy urengoy',
#  'sabang',
#  'spring creek',
#  'zimovniki',
#  'pleiku',
#  'ardakan',
#  'shira',
#  'tumayr',
#  'lata',
#  'ubari',
#  'castillos',
#  'port macquarie',
#  'ipora',
#  'khost',
#  'saint-joseph',
#  'ushtobe',
#  'zhalantun',
#  'san felipe',
#  'yangor',
#  'new plymouth',
#  'mount isa',
#  'myanaung',
#  'porto novo',
#  'maun',
#  'barguzin',
#  'ouahigouya',
#  'la sarre',
#  'gilgit',
#  'worthington',
#  'novi sanzhary',
#  'labrador city',
#  "ust'-barguzin",
#  'ghanzi',
#  'okoneshnikovo',
#  'guerrero negro',
#  'pemba',
#  'portland',
#  'kasane',
#  "'ain el turk",
#  'jacmel',
#  'ouadda',
#  'radnevo',
#  'lupane',
#  'viljoenskroon',
#  'menongue',
#  'masuguru',
#  'cable beach',
#  'tuy hoa',
#  'choyr',
#  'santa cruz',
#  'cockburn town',
#  'eisfeld',
#  'sangmelima',
#  'aleksandrovsk',
#  'buritizeiro',
#  "'ohonua",
#  'parlakimidi',
#  'sandnessjoen',
#  'korsakov',
#  'wamba',
#  'antsiranana',
#  'uglegorsk',
#  'bel ombre',
#  'woolgoolga',
#  'ancud',
#  'namsos',
#  'lazaro cardenas',
#  'smithers',
#  'mount gambier',
#  'burela de cabo',
#  'santa eularia des riu',
#  'mekhe',
#  'kilju',
#  "sho'rchi",
#  'veinticinco de mayo',
#  'porto seguro',
#  "novosokol'niki",
#  'norrtalje',
#  'swan hill',
#  'yelabuga',
#  'alesund',
#  'geraldton',
#  "dem'yanovo",
#  'high rock',
#  'tanjung pandan',
#  'bozkurt',
#  "ivdel'",
#  'saldanha',
#  'manado',
#  'hebi',
#  'tulsipur',
#  'zyrya',
#  'boqueirao',
#  'lethem',
#  'malaya vishera',
#  'walvis bay',
#  'aginskoye',
#  'yreka',
#  'gorodoviki',
#  'port blair',
#  'vila velha',
#  'yemva',
#  'eastham',
#  'bela',
#  'dausa',
#  'sao jose da coroa grande',
#  'melfort',
#  'kittila',
#  'damghan',
#  'mohr',
#  'aleksandrovsk-sakhalinskiy',
#  'auki',
#  'banda aceh',
#  'kourou',
#  'waingapu',
#  'oriximina',
#  'yakeshi',
#  'mugia',
#  'barrouallie',
#  'carutapera',
#  'la passe',
#  'soio',
#  'murghob',
#  'vorkuta',
#  'laguna',
#  'guixi',
#  'bridgewater',
#  'weno',
#  'argo',
#  'leava',
#  'rubtsovsk',
#  'ta`u',
#  'kenai',
#  'sinop',
#  'qasr-e qand',
#  'hamilton',
#  'chulakkurgan',
#  'behshahr',
#  'khovd',
#  'mrakovo',
#  'valley city',
#  'arteche',
#  'kailua-kona',
#  'amungan',
#  "port saint john's",
#  'lake havasu city']

# %%
weather_api_key
# Out:
# '59497c1ce13b25796ec931a58fd75e19'

# %%
city_data=[]
testurl = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&q=likiep"
test = requests.get(testurl).json()
pprint(test)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 9.8251, 'lon': 169.3107},
#  'dt': 1707624195,
#  'id': 2080115,
#  'main': {'feels_like': 299.8,
#           'grnd_level': 1010,
#           'humidity': 74,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 299.8,
#           'temp_max': 299.8,
#           'temp_min': 299.8},
#  'name': 'Likiep',
#  'sys': {'country': 'MH', 'sunrise': 1707591824, 'sunset': 1707634222},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 59, 'gust': 9.62, 'speed': 8.47}}

# %%
test["dt"]
# Out:
# 1707624195

# %%
try:
        # Parse the JSON and retrieve data
    city_weather = test

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
    city_lat = city_weather["coord"]["lat"]
    city_lon = city_weather["coord"]["lon"]
    city_max_temp = city_weather["main"]["temp_max"]
    city_humidity = city_weather["main"]["humidity"]
    city_clouds = city_weather["clouds"]["all"]
    city_wind = city_weather["wind"]["speed"]
    city_country = city_weather["sys"]["country"]
    city_date = city_weather["dt"]

        # Append the City information into city_data list
    city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "lon": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
except:
    print("City not found. Skipping...")
    pass

city_data
# Out:
# [{'City': 'lake havasu city',
#   'Lat': 9.8251,
#   'lon': 169.3107,
#   'Max Temp': 299.8,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 8.47,
#   'Country': 'MH',
#   'Date': 1707624195}]

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1 #first set starts with 1, doesn't satisfy if (i % 50 == 0 and i >= 50), so manually set it to 1 at first
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0 #reset the count of cities back to 0

    # Create endpoint URL with each city
    city_url = url + f"&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "lon": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | kapa'a
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | crane
# Processing Record 6 of Set 1 | salaqi
# Processing Record 7 of Set 1 | bilibino
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | vernon
# Processing Record 10 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | wailua homesteads
# Processing Record 12 of Set 1 | kudahuvadhoo
# Processing Record 13 of Set 1 | invercargill
# Processing Record 14 of Set 1 | marat
# Processing Record 15 of Set 1 | papatowai
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | mejit
# Processing Record 20 of Set 1 | el calafate
# Processing Record 21 of Set 1 | coquimbo
# Processing Record 22 of Set 1 | manokwari
# Processing Record 23 of Set 1 | chateaubelair
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | waitangi
# Processing Record 26 of Set 1 | muynoq
# Processing Record 27 of Set 1 | grytviken
# Processing Record 28 of Set 1 | port mathurin
# Processing Record 29 of Set 1 | nemuro
# Processing Record 30 of Set 1 | ambalangoda
# Processing Record 31 of Set 1 | utrik
# Processing Record 32 of Set 1 | tura
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 1 | arno
# Processing Record 36 of Set 1 | oxford
# Processing Record 37 of Set 1 | urengoy
# Processing Record 38 of Set 1 | tolanaro
# Processing Record 39 of Set 1 | tralee
# Processing Record 40 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 41 of Set 1 | sofiyivka
# Processing Record 42 of Set 1 | albertina
# Processing Record 43 of Set 1 | adamstown
# Processing Record 44 of Set 1 | kingston
# Processing Record 45 of Set 1 | enoch
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | villa gesell
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | stanley
# Processing Record 50 of Set 1 | taulaga
# Processing Record 0 of Set 2 | beloyarskiy
# Processing Record 1 of Set 2 | maine soroa
# Processing Record 2 of Set 2 | vilyuysk
# Processing Record 3 of Set 2 | bargara
# City not found. Skipping...
# Processing Record 4 of Set 2 | bonny
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 
# Processing Record 6 of Set 4 | kununurra
# Processing Record 7 of Set 4 | sao felix do xingu
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | juan griego
# Processing Record 10 of Set 4 | prince rupert
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | camarinas
# Processing Record 13 of Set 4 | nabire
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | mahina
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | yanam
# Processing Record 18 of Set 4 | santiago de cao
# Processing Record 19 of Set 4 | bubaque
# Processing Record 20 of Set 4 | gisborne
# Processing Record 21 of Set 4 | rongelap
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | remire-montjoly
# Processing Record 24 of Set 4 | badger
# Processing Record 25 of Set 4 | guarapari
# Processing Record 26 of Set 4 | kristiansund
# Processing Record 27 of Set 4 | margate
# Processing Record 28 of Set 4 | at taj
# Processing Record 29 of Set 4 | kwang binh
# Processing Record 30 of Set 4 | chibougamau
# Processing Record 31 of Set 4 | niafunke
# Processing Record 32 of Set 4 | dubbo
# Processing Record 33 of Set 4 | road town
# Processing Record 34 of Set 4 | kupang
# Processing Record 35 of Set 4 | bouafle
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | bontang
# Processing Record 38 of Set 4 | tauranga
# Processing Record 39 of Set 4 | port alfred
# Processing Record 40 of Set 4 | udachny
# Processing Record 41 of Set 4 | margaret river
# Processing Record 42 of Set 4 | queenstown
# Processing Record 43 of Set 4 | hammerfest
# Processing Record 44 of Set 4 | rye
# Processing Record 45 of Set 4 | lerwick
# Processing Record 46 of Set 4 | piti village
# Processing Record 47 of Set 4 | kidal
# Processing Record 48 of Set 4 | kuanda
# Processing Record 49 of Set 4 | mora
# Processing Record 0 of Set 5 | wau
# Processing Record 1 of Set 5 | island harbour
# Processing Record 2 of Set 5 | al kharijah
# Processing Record 3 of Set 5 | north lakhimpur
# Processing Record 4 of Set 5 | holualoa
# Processing Record 5 of Set 5 | brisas de zicatela
# Processing Record 6 of Set 5 | uturoa
# Processing Record 7 of Set 5 | lorengau
# Processing Record 8 of Set 5 | pimentel
# Processing Record 9 of Set 5 | selkirk
# Processing Record 10 of Set 5 | arar
# Processing Record 11 of Set 5 | tofol
# Processing Record 12 of Set 5 | nole
# Processing Record 13 of Set 5 | iskateley
# Processing Record 14 of Set 5 | valparaiso
# Processing Record 15 of Set 5 | usogorsk
# Processing Record 16 of Set 5 | hami
# Processing Record 17 of Set 5 | paka
# Processing Record 18 of Set 5 | aasiaat
# Processing Record 19 of Set 5 | alappuzha
# Processing Record 20 of Set 5 | tefe
# Processing Record 21 of Set 5 | palikir - national government center
# Processing Record 22 of Set 5 | jaru
# Processing Record 23 of Set 5 | pokaran
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | fale old settlement
# Processing Record 26 of Set 5 | rudnyy
# Processing Record 27 of Set 5 | jayapura
# Processing Record 28 of Set 5 | selfoss
# Processing Record 29 of Set 5 | khoyniki
# Processing Record 30 of Set 5 | guaimaca
# Processing Record 31 of Set 5 | enewetak
# Processing Record 32 of Set 5 | tual
# Processing Record 33 of Set 5 | belyy yar
# Processing Record 34 of Set 5 | atafu village
# Processing Record 35 of Set 5 | ust'-ilimsk
# Processing Record 36 of Set 5 | igarka
# Processing Record 6 of Set 9 | sao joao da barra
# Processing Record 7 of Set 9 | farah
# Processing Record 8 of Set 9 | mutare
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | sorgun
# Processing Record 11 of Set 9 | puerto colombia
# Processing Record 12 of Set 9 | buckeye
# Processing Record 13 of Set 9 | edd
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | ciudad del carmen
# Processing Record 16 of Set 9 | mitu
# Processing Record 17 of Set 9 | twin falls
# Processing Record 18 of Set 9 | yuzhno-kurilsk
# Processing Record 19 of Set 9 | happy valley-goose bay
# Processing Record 20 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 21 of Set 9 | novyy urengoy
# Processing Record 22 of Set 9 | sabang
# Processing Record 23 of Set 9 | spring creek
# Processing Record 24 of Set 9 | zimovniki
# Processing Record 25 of Set 9 | pleiku
# Processing Record 26 of Set 9 | ardakan
# Processing Record 27 of Set 9 | shira
# Processing Record 28 of Set 9 | tumayr
# Processing Record 29 of Set 9 | lata
# Processing Record 30 of Set 9 | ubari
# Processing Record 31 of Set 9 | castillos
# Processing Record 32 of Set 9 | port macquarie
# Processing Record 33 of Set 9 | ipora
# Processing Record 34 of Set 9 | khost
# Processing Record 35 of Set 9 | saint-joseph
# Processing Record 36 of Set 9 | ushtobe
# Processing Record 37 of Set 9 | zhalantun
# Processing Record 38 of Set 9 | san felipe
# Processing Record 39 of Set 9 | yangor
# City not found. Skipping...
# Processing Record 40 of Set 9 | new plymouth
# Processing Record 41 of Set 9 | mount isa
# Processing Record 42 of Set 9 | myanaung
# Processing Record 43 of Set 9 | porto novo
# Processing Record 44 of Set 9 | maun
# Processing Record 45 of Set 9 | barguzin
# Processing Record 46 of Set 9 | ouahigouya
# Processing Record 47 of Set 9 | la sarre
# Processing Record 48 of Set 9 | gilgit
# Processing Record 49 of Set 9 | worthington
# Processing Record 0 of Set 10 | novi sanzhary
# Processing Record 1 of Set 10 | labrador city
# Processing Record 2 of Set 10 | ust'-barguzin
# Processing Record 3 of Set 10 | ghanzi
# Processing Record 4 of Set 10 | okoneshnikovo
# Processing Record 5 of Set 10 | guerrero negro
# Processing Record 6 of Set 10 | pemba
# Processing Record 7 of Set 10 | portland
# Processing Record 8 of Set 10 | kasane
# Processing Record 9 of Set 10 | 'ain el turk
# Processing Record 10 of Set 10 | jacmel
# Processing Record 11 of Set 10 | ouadda
# Processing Record 12 of Set 10 | radnevo
# Processing Record 13 of Set 10 | lupane
# Processing Record 14 of Set 10 | viljoenskroon
# Processing Record 15 of Set 10 | menongue
# Processing Record 16 of Set 10 | masuguru
# Processing Record 17 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 18 of Set 10 | tuy hoa
# Processing Record 19 of Set 10 | choyr
# Processing Record 20 of Set 10 | santa cruz
# Processing Record 21 of Set 10 | cockburn town
# Processing Record 22 of Set 10 | eisfeld
# Processing Record 23 of Set 10 | sangmelima
# Processing Record 24 of Set 10 | aleksandrovsk
# Processing Record 25 of Set 10 | buritizeiro
# Processing Record 26 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 27 of Set 10 | parlakimidi
# Processing Record 28 of Set 10 | sandnessjoen
# Processing Record 29 of Set 10 | korsakov
# Processing Record 30 of Set 10 | wamba
# Processing Record 31 of Set 10 | antsiranana
# Processing Record 32 of Set 10 | uglegorsk
# Processing Record 33 of Set 10 | bel ombre
# Processing Record 34 of Set 10 | woolgoolga
# Processing Record 35 of Set 10 | ancud
# Processing Record 36 of Set 10 | namsos
# Processing Record 37 of Set 10 | lazaro cardenas
# Processing Record 38 of Set 10 | smithers
# Processing Record 39 of Set 10 | mount gambier
# Processing Record 40 of Set 10 | burela de cabo
# Processing Record 41 of Set 10 | santa eularia des riu
# Processing Record 42 of Set 10 | mekhe
# Processing Record 43 of Set 10 | kilju
# Processing Record 44 of Set 10 | sho'rchi
# Processing Record 45 of Set 10 | veinticinco de mayo
# Processing Record 46 of Set 10 | porto seguro
# Processing Record 47 of Set 10 | novosokol'niki
# Processing Record 48 of Set 10 | norrtalje
# Processing Record 49 of Set 10 | swan hill
# Processing Record 0 of Set 11 | yelabuga
# Processing Record 1 of Set 11 | alesund
# Processing Record 2 of Set 11 | geraldton
# Processing Record 3 of Set 11 | dem'yanovo
# Processing Record 4 of Set 11 | high rock
# Processing Record 5 of Set 11 | tanjung pandan
# Processing Record 6 of Set 11 | bozkurt
# Processing Record 7 of Set 11 | ivdel'
# Processing Record 8 of Set 11 | saldanha
# Processing Record 9 of Set 11 | manado
# Processing Record 10 of Set 11 | hebi
# Processing Record 11 of Set 11 | tulsipur
# Processing Record 12 of Set 11 | zyrya
# Processing Record 13 of Set 11 | boqueirao
# Processing Record 14 of Set 11 | lethem
# Processing Record 15 of Set 11 | malaya vishera
# Processing Record 16 of Set 11 | walvis bay
# Processing Record 17 of Set 11 | aginskoye
# Processing Record 18 of Set 11 | yreka
# Processing Record 19 of Set 11 | gorodoviki
# Processing Record 20 of Set 11 | port blair
# Processing Record 21 of Set 11 | vila velha
# Processing Record 22 of Set 11 | yemva
# Processing Record 23 of Set 11 | eastham
# Processing Record 24 of Set 11 | bela
# Processing Record 25 of Set 11 | dausa
# Processing Record 26 of Set 11 | sao jose da coroa grande
# Processing Record 27 of Set 11 | melfort
# Processing Record 28 of Set 11 | kittila
# Processing Record 29 of Set 11 | damghan
# Processing Record 30 of Set 11 | mohr
# Processing Record 31 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 32 of Set 11 | auki
# Processing Record 33 of Set 11 | banda aceh
# Processing Record 34 of Set 11 | kourou
# Processing Record 35 of Set 11 | waingapu
# Processing Record 36 of Set 11 | oriximina
# Processing Record 37 of Set 11 | yakeshi
# Processing Record 38 of Set 11 | mugia
# Processing Record 39 of Set 11 | barrouallie
# Processing Record 40 of Set 11 | carutapera
# Processing Record 41 of Set 11 | la passe
# Processing Record 42 of Set 11 | soio
# Processing Record 43 of Set 11 | murghob
# Processing Record 44 of Set 11 | vorkuta
# Processing Record 45 of Set 11 | laguna
# Processing Record 46 of Set 11 | guixi
# Processing Record 47 of Set 11 | bridgewater
# Processing Record 48 of Set 11 | weno
# Processing Record 49 of Set 11 | argo
# Processing Record 0 of Set 12 | leava
# Processing Record 1 of Set 12 | rubtsovsk
# Processing Record 2 of Set 12 | ta`u
# Processing Record 3 of Set 12 | kenai
# Processing Record 4 of Set 12 | sinop
# Processing Record 5 of Set 12 | qasr-e qand
# City not found. Skipping...
# Processing Record 6 of Set 12 | hamilton
# Processing Record 7 of Set 12 | chulakkurgan
# Processing Record 8 of Set 12 | behshahr
# Processing Record 9 of Set 12 | khovd
# Processing Record 10 of Set 12 | mrakovo
# Processing Record 11 of Set 12 | valley city
# Processing Record 12 of Set 12 | arteche
# Processing Record 13 of Set 12 | kailua-kona
# Processing Record 14 of Set 12 | amungan
# Processing Record 15 of Set 12 | port saint john's
# Processing Record 16 of Set 12 | lake havasu city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          553
# Lat           553
# lon           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       lon  Max Temp  Humidity  Cloudiness  \
# 0  puerto natales -51.7236  -72.4875    283.23        91         100
# 1          kapa'a  22.0752 -159.3190    296.33        80          75
# 2  port elizabeth -33.9180   25.5701    286.66        86           0
# 3     east london -33.0153   27.9116    288.67        94          40
# 4           crane  31.3974 -102.3501    287.78        31          91
#
#    Wind Speed Country        Date
# 0        1.65      CL  1707624041
# 1        4.12      US  1707623930
# 2        1.54      ZA  1707623919
# 3        0.51      ZA  1707623954
# 4        7.20      US  1707624195

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       lon  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236  -72.4875    283.23        91         100
# 1                kapa'a  22.0752 -159.3190    296.33        80          75
# 2        port elizabeth -33.9180   25.5701    286.66        86           0
# 3           east london -33.0153   27.9116    288.67        94          40
# 4                 crane  31.3974 -102.3501    287.78        31          91
#
#          Wind Speed Country        Date
# City_ID
# 0              1.65      CL  1707624041
# 1              4.12      US  1707623930
# 2              1.54      ZA  1707623919
# 3              0.51      ZA  1707623954
# 4              7.20      US  1707624195

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Lat", y="Max Temp", xlabel="Latitude", ylabel="Max Temperature (K)", 
                  title="City Latitude vs Max Temperature (2023-06-18)", color="#FFC300")

# Incorporate the other graph properties
plt.grid(alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Lat", y="Humidity", xlabel="Latitude", ylabel="Humidity (%)", 
                  title="City Latitude vs Humidity (2023-06-18)", color="#FFC300")

# Incorporate the other graph properties
plt.grid(alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter", x="Lat", y="Cloudiness", xlabel="Latitude", ylabel="Cloudiness (%)", 
                  title="City Latitude vs Cloudiness (2023-06-18)", color="#FFC300")

# Incorporate the other graph properties
plt.grid(alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter", x="Lat", y="Wind Speed", xlabel="Latitude", ylabel="Wind Speed (m/s)", 
                  title="City Latitude vs Wind Speed (2023-06-18)", color="#FFC300")

# Incorporate the other graph properties
plt.grid(alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Define a function to create Linear Regression plots
def plotlinregress(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y, color="#899878")
    plt.plot(x, regress_values, color="#222725")
    return line_eq
def rvalue(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    return f"r = {round(rvalue,4)}"

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.sample(10)
# Out:
#                           City      Lat       lon  Max Temp  Humidity  \
# City_ID
# 544                   behshahr  36.6923   53.5526    279.12        47
# 364                    vitebsk  55.1905   30.2033    268.39        92
# 459              cockburn town  21.4612  -71.1419    297.13        64
# 224                   guaimaca  14.5333  -86.8167    290.47        87
# 368                      kalix  65.8530   23.1565    249.08       100
# 98                  kralendijk  12.1500  -68.2667    299.70        85
# 324                   kargasok  59.0556   80.8572    260.14        90
# 125      drobeta-turnu severin  44.6319   22.6561    283.72        70
# 5                       salaqi  40.5414  110.5108    268.57        71
# 542                   hamilton  39.1834  -84.5333    280.32        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 544              34        1.52      IR  1707624268
# 364             100        4.89      BY  1707624038
# 459              91        9.60      TC  1707624257
# 224               0        1.54      HN  1707624221
# 368              88        1.49      SE  1707624237
# 98                0       10.32      BQ  1707624113
# 324             100        7.44      RU  1707624232
# 125             100        2.31      RO  1707624210
# 5                 9        2.29      CN  1707624195
# 542             100        2.24      US  1707624128

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.sample(10)
# Out:
#                       City      Lat       lon  Max Temp  Humidity  Cloudiness  \
# City_ID
# 297           saint-pierre -21.3393   55.4781    299.97        74           0
# 294       flying fish cove -10.4217  105.6791    301.97        74          75
# 454               menongue -14.6585   17.6910    290.64        90          94
# 183            port alfred -33.5906   26.8910    290.06        76          46
# 65           blackmans bay -43.0167  147.3167    296.77        48          64
# 433                   maun -19.9833   23.4167    298.13        69           0
# 123            alto parana -23.1289  -52.3189    297.30        55          99
# 169              guarapari -20.6667  -40.4975    295.87        89          92
# 397      sao joao da barra -21.6403  -41.0511    295.68        87          16
# 142               kerikeri -35.2268  173.9474    295.88        51           0
#
#          Wind Speed Country        Date
# City_ID
# 297            2.06      RE  1707624204
# 294            2.57      CX  1707624228
# 454            0.76      AO  1707624256
# 183            1.37      ZA  1707624216
# 65             3.95      AU  1707624203
# 433            2.57      BW  1707624249
# 123            1.02      BR  1707624210
# 169            2.98      BR  1707624215
# 397            5.04      BR  1707624217
# 142            1.34      NZ  1707624212

# %%
# Linear regression on Northern Hemisphere
plot = plotlinregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.annotate(plot, xy=(50,310), xytext=(5,5), textcoords='offset points',color="#222725")
plt.annotate(rvalue(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"]), xy=(50,307), xytext=(5,5), textcoords='offset points',color="#222725")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.title("Northern Hemisphere: Temperature vs. Latitude")
plt.savefig("output_data/Fig5.png")
plt.show()

# %%
# Linear regression on Southern Hemisphere
plot = plotlinregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.annotate(plot, xy=(-55,301.5), xytext=(5,5), textcoords='offset points',color="#222725")
plt.annotate(rvalue(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"]), xy=(-55,299.5), xytext=(5,5), textcoords='offset points',color="#222725")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.title("Southern Hemisphere: Temperature vs. Latitude")
plt.savefig("output_data/Fig6.png")
plt.show()

# %%
# Northern Hemisphere
plot = plotlinregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
plt.annotate(plot, xy=(55,15), xytext=(5,5), textcoords='offset points',color="#222725")
plt.annotate(rvalue(northern_hemi_df["Lat"], northern_hemi_df["Humidity"]), xy=(55,10), xytext=(5,5), textcoords='offset points',color="#222725")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Northern Hemisphere: Humidity vs. Latitude")
plt.savefig("output_data/Fig7.png")
plt.show()

# %%
# Southern Hemisphere
plot = plotlinregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
plt.annotate(plot, xy=(-55,30), xytext=(5,5), textcoords='offset points',color="#222725")
plt.annotate(rvalue(southern_hemi_df["Lat"], southern_hemi_df["Humidity"]), xy=(-55,25), xytext=(5,5), textcoords='offset points',color="#222725")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Southern Hemisphere: Humidity vs. Latitude")
plt.savefig("output_data/Fig8.png")
plt.show()

# %%
# Northern Hemisphere
plot = plotlinregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
plt.annotate(plot, xy=(40,48), xytext=(5,5), textcoords='offset points',color="#222725")
plt.annotate(rvalue(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"]), xy=(40,43), xytext=(5,5), textcoords='offset points',color="#222725")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Northern Hemisphere: Cloudiness vs. Latitude")
plt.savefig("output_data/Fig9.png")
plt.show()

# %%
# Southern Hemisphere
plot = plotlinregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
plt.annotate(plot, xy=(-56,87), xytext=(5,5), textcoords='offset points',color="#222725")
plt.annotate(rvalue(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"]), xy=(-56,82), xytext=(5,5), textcoords='offset points',color="#222725")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Southern Hemisphere: Cloudiness vs. Latitude")
plt.savefig("output_data/Fig10.png")
plt.show()

# %%
# Northern Hemisphere
plot = plotlinregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
plt.annotate(plot, xy=(55,10.8), xytext=(5,5), textcoords='offset points',color="#222725")
plt.annotate(rvalue(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"]), xy=(55,10), xytext=(5,5), textcoords='offset points',color="#222725")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title("Northern Hemisphere: Wind Speed vs. Latitude")
plt.savefig("output_data/Fig11.png")
plt.show()

# %%
# Southern Hemisphere
plot = plotlinregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
plt.annotate(plot, xy=(-55,12.2), xytext=(5,5), textcoords='offset points',color="#222725")
plt.annotate(rvalue(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"]), xy=(-55,11.4), xytext=(5,5), textcoords='offset points',color="#222725")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title("Southern Hemisphere: Wind Speed vs. Latitude")
plt.savefig("output_data/Fig12.png")
plt.show()
